# %%
import pandas as pd

# %%
url = 'C:/GitHub/BIA-Team-Bravo/Data/raw/Canada Debt.csv'
df = pd.read_csv(url)

# %%
df.columns
# Out:
# Index(['REF_DATE', 'GEO', 'DGUID', 'Estimates', 'UOM', 'UOM_ID',
#        'SCALAR_FACTOR', 'SCALAR_ID', 'VECTOR', 'COORDINATE', 'VALUE', 'STATUS',
#        'SYMBOL', 'TERMINATED', 'DECIMALS'],
#       dtype='str')

# %%
df
# Out:
#       REF_DATE               GEO           DGUID  \
# 0         2015            Canada  2016A000011124
# 1         2016            Canada  2016A000011124
# 2         2017            Canada  2016A000011124
# 3         2018            Canada  2016A000011124
# 4         2019            Canada  2016A000011124
# ...        ...               ...             ...
# 1535      2020  British Columbia     2016A000259
# 1536      2021  British Columbia     2016A000259
# 1537      2022  British Columbia     2016A000259
# 1538      2023  British Columbia     2016A000259
# 1539      2024  British Columbia     2016A000259
#
#                                       Estimates      UOM  UOM_ID  \
# 0                              Household income  Dollars      81
# 1                              Household income  Dollars      81
# 2                              Household income  Dollars      81
# 3                              Household income  Dollars      81
# ...

# %%
ef = df[['GEO', 'Estimates', 'VALUE']]

# %%
ef[ef['Estimates'] == 'Equals: debt service ratio, interest only']
# Out:
#                        GEO                                  Estimates  VALUE
# REF_DATE
# 2015                Canada  Equals: debt service ratio, interest only   6.41
# 2016                Canada  Equals: debt service ratio, interest only   6.47
# 2017                Canada  Equals: debt service ratio, interest only   6.48
# 2018                Canada  Equals: debt service ratio, interest only   7.06
# 2019                Canada  Equals: debt service ratio, interest only   7.43
# ...                    ...                                        ...    ...
# 2020      British Columbia  Equals: debt service ratio, interest only   7.22
# 2021      British Columbia  Equals: debt service ratio, interest only   6.63
# 2022      British Columbia  Equals: debt service ratio, interest only   7.82
# 2023      British Columbia  Equals: debt service ratio, interest only  10.06
# 2024      British Columbia  Equals: debt service ratio, interest only  10.28
#
# [110 rows x 3 columns]

# %%
ef.to_csv('C:\GitHub\BIA-Team-Bravo\Data\Clean\Canada Debt')
