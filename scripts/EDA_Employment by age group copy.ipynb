# %%
import pandas as pd
import plotly.express as px

# %%
url = '../data/clean/Labour force characteristics by age group,gender StatCanada.csv'
df = pd.read_csv(url)
df
# Out:
#           REF_DATE     GEO Labour force characteristics          Gender  \
# 0       2015-01-01  Canada                   Population  Total - Gender
# 1       2015-02-01  Canada                   Population  Total - Gender
# 2       2015-03-01  Canada                   Population  Total - Gender
# 3       2015-04-01  Canada                   Population  Total - Gender
# 4       2015-05-01  Canada                   Population  Total - Gender
# ...            ...     ...                          ...             ...
# 568210  2025-11-01  Canada                   Employment  Total - Gender
# 568211  2025-12-01  Canada                   Employment  Total - Gender
# 568212  2026-01-01  Canada                   Employment  Total - Gender
# 568213  2026-02-01  Canada                   Employment  Total - Gender
# 568214  2026-03-01  Canada                   Employment  Total - Gender
#
#                 Age group Statistics    Data type    VALUE
# ...

# %%
df2 = df[(df['Labour force characteristics'] == 'Employment rate') 
   & (df['Gender'] == 'Total - Gender')
   & (df['Data type'] == 'Seasonally adjusted')
   ]

# %%
for province in df['GEO'].value_counts().index:
    fig = px.line(df2[(df['GEO'] == province)], 'REF_DATE', 'VALUE', color = 'Age group', title=f'{province} Employment by Age Group')
    fig.show()
# Out:
# C:\Users\MGarn\AppData\Local\Temp\ipykernel_28956\2328541211.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   fig = px.line(df2[(df['GEO'] == province)], 'REF_DATE', 'VALUE', color = 'Age group', title=f'{province} Employment by Age Group')
# C:\Users\MGarn\AppData\Local\Temp\ipykernel_28956\2328541211.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   fig = px.line(df2[(df['GEO'] == province)], 'REF_DATE', 'VALUE', color = 'Age group', title=f'{province} Employment by Age Group')
# C:\Users\MGarn\AppData\Local\Temp\ipykernel_28956\2328541211.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   fig = px.line(df2[(df['GEO'] == province)], 'REF_DATE', 'VALUE', color = 'Age group', title=f'{province} Employment by Age Group')
# C:\Users\MGarn\AppData\Local\Temp\ipykernel_28956\2328541211.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# ...

# %%
df3 = df[(df['Gender'] == 'Total - Gender')
   & ((df['Labour force characteristics'] == 'Full-time employment') | (df['Labour force characteristics'] == 'Part-time employment'))
   & (df['Age group'] == '15 years and over')
   & (df['Data type'] == 'Seasonally adjusted')
]
df3
# Out:
#           REF_DATE     GEO Labour force characteristics          Gender  \
# 557820  2015-01-01  Canada         Full-time employment  Total - Gender
# 557821  2015-02-01  Canada         Full-time employment  Total - Gender
# 557822  2015-03-01  Canada         Full-time employment  Total - Gender
# 557823  2015-04-01  Canada         Full-time employment  Total - Gender
# 557824  2015-05-01  Canada         Full-time employment  Total - Gender
# ...            ...     ...                          ...             ...
# 560785  2025-11-01  Canada         Part-time employment  Total - Gender
# 560786  2025-12-01  Canada         Part-time employment  Total - Gender
# 560787  2026-01-01  Canada         Part-time employment  Total - Gender
# 560788  2026-02-01  Canada         Part-time employment  Total - Gender
# 560789  2026-03-01  Canada         Part-time employment  Total - Gender
#
#                 Age group Statistics            Data type    VALUE
# ...

# %%
for province in df['GEO'].value_counts().index:
    fig = px.line(df3[(df['GEO'] == province)], 'REF_DATE', 'VALUE', color = 'Labour force characteristics', title=f'{province} Employment by Part-Time vs. Full-Time')
    fig.show()
# Out:
# C:\Users\MGarn\AppData\Local\Temp\ipykernel_28956\719573810.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   fig = px.line(df3[(df['GEO'] == province)], 'REF_DATE', 'VALUE', color = 'Labour force characteristics', title=f'{province} Employment by Part-Time vs. Full-Time')
# C:\Users\MGarn\AppData\Local\Temp\ipykernel_28956\719573810.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   fig = px.line(df3[(df['GEO'] == province)], 'REF_DATE', 'VALUE', color = 'Labour force characteristics', title=f'{province} Employment by Part-Time vs. Full-Time')
# C:\Users\MGarn\AppData\Local\Temp\ipykernel_28956\719573810.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   fig = px.line(df3[(df['GEO'] == province)], 'REF_DATE', 'VALUE', color = 'Labour force characteristics', title=f'{province} Employment by Part-Time vs. Full-Time')
# ...

# %%
df4 = df[(df['Labour force characteristics'] == 'Participation rate') 
   & (df['Gender'] == 'Total - Gender')
   & (df['Data type'] == 'Seasonally adjusted')
   ]

# %%
for province in df['GEO'].value_counts().index:
    fig = px.line(df4[(df['GEO'] == province)], 'REF_DATE', 'VALUE', color = 'Age group', title=f'{province} Employment by Part-Time vs. Full-Time')
    fig.show()
# Out:
# C:\Users\MGarn\AppData\Local\Temp\ipykernel_28956\396811834.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   fig = px.line(df4[(df['GEO'] == province)], 'REF_DATE', 'VALUE', color = 'Age group', title=f'{province} Employment by Part-Time vs. Full-Time')
# C:\Users\MGarn\AppData\Local\Temp\ipykernel_28956\396811834.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   fig = px.line(df4[(df['GEO'] == province)], 'REF_DATE', 'VALUE', color = 'Age group', title=f'{province} Employment by Part-Time vs. Full-Time')
# C:\Users\MGarn\AppData\Local\Temp\ipykernel_28956\396811834.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   fig = px.line(df4[(df['GEO'] == province)], 'REF_DATE', 'VALUE', color = 'Age group', title=f'{province} Employment by Part-Time vs. Full-Time')
# ...

# %%
df['Labour force characteristics'].value_counts()
# Out:
# Labour force characteristics
# Employment              65475
# Population              63990
# Labour force            63990
# Unemployment            63990
# Unemployment rate       63990
# Participation rate      63990
# Employment rate         63990
# Full-time employment    59400
# Part-time employment    59400
# Name: count, dtype: int64

# %%
df['GEO'].value_counts().index
# Out:
# Index(['Canada', 'Newfoundland and Labrador', 'Prince Edward Island',
#        'Nova Scotia', 'New Brunswick', 'Quebec', 'Ontario', 'Manitoba',
#        'Saskatchewan', 'Alberta', 'British Columbia'],
#       dtype='str', name='GEO')

# %%
df['Labour force characteristics'].value_counts().index
# Out:
# Index(['Employment', 'Population', 'Labour force', 'Unemployment',
#        'Unemployment rate', 'Participation rate', 'Employment rate',
#        'Full-time employment', 'Part-time employment'],
#       dtype='str', name='Labour force characteristics')
