# %%
import pandas as pd
import plotly.express as px

# %%
url = '../data/clean/Annual Payday Loan Clean Data.csv'
df = pd.read_csv(url, index_col=0)
df
# Out:
#                  Period Covered  No. borrowers granted > 1 loan  \
# 0   July 1, 2015- June 30, 2016                         23744.0
# 1  July 1, 2016 - June 30, 2017                         24050.0
# 2  July 1, 2017 - June 30, 2018                         22838.0
# 3  July 1, 2018 - June 30, 2019                         23369.0
# 4  July 1, 2019 - June 30, 2020                         22517.0
# 5  July 1, 2020 - June 30, 2021                         15290.0
# 6  July 1, 2021 - June 30, 2022                         17333.0
# 7  July 1, 2022 - June 30, 2023                         17876.0
# 8  July 1, 2023 - June 30, 2024                         18714.0
# 9  July 1, 2024 - June 30, 2025                         20293.0
#
#    No. of repeat loans granted  No. borrowers granted repeat loans  \
# 0                     115378.0                             17665.0
# 1                     117896.0                             18795.0
# ...

# %%
fig = px.line(df, x = 'Period Covered', y = 'Default Rate')
fig.show()

# %%
fig = px.line(df, x = 'Period Covered', y = 'Average Amount Loan Defaulted')
fig.show()

# %%
fig = px.line(df, x = 'Period Covered', y = 'Estimated Total Value of Loans Granted')
fig.show()

# %%
fig = px.line(df, x = 'Period Covered', y = 'Total Loans Granted')
fig.show()
