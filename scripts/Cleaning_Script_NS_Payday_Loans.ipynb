# %%
import pandas as pd

# %%
url = '../data/raw/NS minimum Wage(2016-2026).csv'
df = pd.read_csv(url)

# %%
df = df[[df.columns[0],df.columns[1], "Experience Level"]]

# %%
df.to_csv('../data/clean/NS minimum wage.csv')

# %%
df
# Out:
#    Effective Date  Minimum Wage Rate Provincial Zone Gender  Age  \
# 0      2026-04-01              16.75  Not Applicable    All  All
# 1      2025-10-01              16.50  Not Applicable    All  All
# 2      2025-04-01              15.70  Not Applicable    All  All
# 3      2024-04-01              15.20  Not Applicable    All  All
# 4      2023-10-01              15.00  Not Applicable    All  All
# 5      2023-04-01              14.50  Not Applicable    All  All
# 6      2022-10-01              13.60  Not Applicable    All  All
# 7      2022-04-01              13.35  Not Applicable    All  All
# 8      2021-04-01              12.95  Not Applicable    All  All
# 9      2020-04-01              12.55  Not Applicable    All  All
# 10     2019-04-01              11.55  Not Applicable    All  All
# 11     2019-04-01              11.05  Not Applicable    All  All
# 12     2018-04-01              11.00  Not Applicable    All  All
# ...
