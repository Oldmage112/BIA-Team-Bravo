# %%
import pandas as pd

# %%
url = '../data/raw/Labour force by educational attainment.csv'
df = pd.read_csv(url)

# %%
df = df[['REF_DATE','GEO','Educational attainment','Age group','VALUE']]

# %%
df.to_csv('../data/clean/Cleaned Labour force by educational attainment.csv')
